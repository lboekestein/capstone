# %%
# import .dta file
import pandas as pd
import numpy as np

# %%
# import the data_info_all_svi.dta file
data = pd.read_stata('data_info_all_svi.dta')

# %%
data[100:120]
# Out:
#       v1  article_id   country paper  chadefaux_count  uncertainty  ep  \
# 100  100         101    Bhutan   BBC                0            0  10
# 101  101         102    Bhutan   BBC                0            0   0
# 102  102         103    Bhutan   BBC                0            0   0
# 103  103         104    Bhutan   BBC                1            0   0
# 104  104         105    Bhutan   BBC                0            0   0
# 105  105         106    Bhutan   BBC                0            0   0
# 106  106         107    Bhutan   BBC                2            0   0
# 107  107         108    Bhutan   BBC                0            0  10
# 108  108         109    Bhutan   BBC                0            0   0
# 109  109         110    Bhutan   BBC                0            0   0
# 110  110         111  Kiribati   BBC                0            0   0
# 111  111         112  Kiribati   BBC                0            0   0
# ...
