# %%
import pandas as pd
import urllib.parse
import urllib.error
import pickle
import time
import sys
import glob
from IPython.display import clear_output
import geopandas as gpd
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import plotly.express as px
import pycountry
import numpy as np
import kaleido
import plotly.graph_objects as go

countries_codes_path = '../../data/auxilary_data/countries_iso_fips_capitals.csv'

# %%
country_to_country_all = pd.read_csv('../../data/GDELT/saved_data/country_to_country_all.csv')

# %%
countries_codes = pd.read_csv(countries_codes_path)
# strip trailing whitespaces

countries_codes['GDELT_name'] = countries_codes['GDELT_name'].str.strip()
gdelt_name_to_ISO_dict = dict(zip(countries_codes['GDELT_name'], countries_codes['ISO_alpha3']))

# %%
combined_f = country_to_country_all.drop(columns = ["Date", "Unnamed: 2"])
final_df = combined_f.groupby(["Target country"]).mean().sort_values(by = "Target country")
final_df.head(20)
# Out:
#                      Afghanistan    Albania    Algeria     Angola  Argentina  \
# Target country
# Afghanistan            61.153794   0.722672   0.407648   0.233930   0.123163
# Albania                 0.097081  29.539962   0.046415   0.041323   0.016827
# Algeria                 0.260947   0.084421  39.857927   0.356128   0.073552
# American Samoa          0.002766        NaN   0.001862   0.001263   0.000168
# Andorra                 0.011695   0.033549   0.012754   0.008019   0.051678
# Angola                  0.053214   0.000094   0.354817  56.213320   0.006143
# Anguilla                0.305449   0.021140   1.073368   0.011574   0.425975
# Antigua and Barbuda     0.005622   0.000539   0.000081   0.000316   0.000407
# Argentina               0.313530   0.317176   0.672496   0.436595  31.870900
# Armenia                 0.752210   0.151478   0.039898   0.018200   0.087700
# Aruba                   0.002246   0.001080   0.008297   0.003596   0.007799
# Australia               3.069247   0.706114   0.429112   0.341673   0.320811
# Austria                 0.503691   1.184263   0.450971   0.249936   0.265672
# Azerbaijan              1.337488   0.214798   0.157932   0.051140   0.062694
# Bahrain                 0.505223   0.028134   0.353081   0.059253   0.055200
# Bangladesh              1.171605   0.072326   0.125871   0.022512   0.012097
# Barbados                0.025437   0.019874   0.008160   0.018696   0.048587
# Belarus                 0.708517   0.492771   0.092035   0.183591   0.089293
# Belgium                 1.371210   3.136546   1.327350   0.913399   0.567398
# Belize                  0.014124   0.007802   0.007366   0.058782   0.034376
#
#                        Armenia  Australia    Austria  Azerbaijan    Bahrain  \
# Target country
# Afghanistan           1.084218   0.690159   0.186505    3.598944   0.778591
# Albania               0.186553   0.033172   0.086125    0.395863   0.060133
# Algeria               0.082390   0.042973   0.097514    0.228640   0.656803
# American Samoa        0.000647   0.010499   0.002519    0.000508   0.000562
# Andorra               0.036054   0.005952   0.041431    0.016540   0.007418
# Angola                0.013168   0.034119   0.021003    0.040810   0.043889
# Anguilla              0.172058   1.173790   0.197281    0.128708   0.271839
# Antigua and Barbuda   0.000476   0.006967   0.002088    0.001488   0.002784
# Argentina             0.508660   0.458107   0.340584    0.272012   0.463743
# Armenia              58.904140   0.038121   0.116099   12.053696   0.107673
# Aruba                 0.000277   0.014774   0.007241    0.000404   0.011540
# Australia             0.729020  34.665664   0.750141    0.959346   1.242532
# Austria               1.102257   0.385661  30.285767    0.924138   0.620399
# Azerbaijan           15.042509   0.123376   0.133297   44.856324   0.291693
# Bahrain               0.066433   0.241492   0.007352    0.203615  38.892473
# Bangladesh            0.109880   0.269829   0.096185    0.273851   0.323486
# Barbados              0.008307   0.050922   0.007021    0.009712   0.018770
# Belarus               4.202532   0.139774   0.352918    4.440329   0.199777
# Belgium               1.969334   0.564593   2.018846    1.405292   0.832800
# Belize                0.004621   0.018060   0.017033    0.005121   0.014040
#
#                      ...  United Arab Emirates  United Kingdom  United States  \
# Target country       ...
# Afghanistan          ...              1.125398        0.818044       0.913777
# Albania              ...              0.098717        0.104755       0.070581
# Algeria              ...              0.693201        0.115633       0.097019
# American Samoa       ...              0.003072        0.007657       0.022266
# Andorra              ...              0.011919        0.023211       0.009281
# Angola               ...              0.149222        0.069689       0.064619
# Anguilla             ...              0.382953        0.509876       0.947376
# Antigua and Barbuda  ...              0.011168        0.016603       0.016947
# Argentina            ...              0.811664        0.394575       0.644129
# Armenia              ...              0.172629        0.064859       0.067983
# Aruba                ...              0.018926        0.020062       0.024795
# Australia            ...              2.154041        2.928106       1.891003
# Austria              ...              0.742454        0.524639       0.476376
# Azerbaijan           ...              0.310686        0.099280       0.094752
# Bahrain              ...              3.334119        0.154835       0.162556
# Bangladesh           ...              0.658454        0.243930       0.201342
# Barbados             ...              0.042159        0.126626       0.059404
# Belarus              ...              0.263861        0.216318       0.205481
# Belgium              ...              1.207266        1.874291       0.824500
# Belize               ...              0.025250        0.040823       0.043240
#
#                        Uruguay  Uzbekistan  Venezuela   Vietnam     Yemen  \
# Target country
# Afghanistan           0.240189    4.074993   0.431421  0.033245  0.589670
# Albania               0.027824    0.053563   0.037084  0.002799  0.023954
# Algeria               0.135504    0.097806   0.259118  0.021097  0.518425
# American Samoa             NaN         NaN   0.000184  0.000111  0.000850
# Andorra               0.055879    0.011520   0.104778  0.000376  0.007867
# Angola                0.010566    0.020739   0.021818  0.005245  0.043649
# Anguilla              0.160218    0.331401   0.482181  0.227008  1.271225
# Antigua and Barbuda   0.000334         NaN   0.007617  0.000933  0.000215
# Argentina            12.450069    0.158808   5.242570  0.052392  0.719066
# Armenia               0.063246    0.840127   0.033517  0.005488  0.058877
# Aruba                 0.012210         NaN   0.137246  0.000543  0.004433
# Australia             0.392746    0.475641   0.419367  1.369741  0.694792
# Austria               0.384446    0.756812   0.478104  0.044754  0.290416
# Azerbaijan            0.059180    2.056122   0.107475  0.007655  0.104725
# Bahrain               0.058395    0.097517   0.076537  0.011843  1.251786
# Bangladesh            0.014918    0.231556   0.042998  0.085772  0.233414
# Barbados              0.078036    0.006498   0.456809  0.001408  0.002144
# Belarus               0.113250    2.663302   0.212950  0.017158  0.135210
# Belgium               0.861476    0.956577   0.883792  0.680511  0.501422
# Belize                0.054207    0.005721   0.108187  0.000893  0.011422
#
#                        Zambia  Zimbabwe
# Target country
# Afghanistan          0.060320  0.812661
# Albania              0.019373  0.039245
# Algeria              0.622939  0.670658
# American Samoa            NaN  0.003364
# Andorra              0.021544  0.005676
# Angola               1.465438  1.061150
# Anguilla             0.193495  0.237012
# Antigua and Barbuda  0.015652  0.006852
# Argentina            0.150011  0.408991
# Armenia              0.027316  0.043923
# Aruba                     NaN  0.003029
# Australia            0.555407  2.382296
# Austria              0.220375  0.280035
# Azerbaijan           0.011884  0.112503
# Bahrain              0.025177  0.180039
# Bangladesh           0.061563  0.686532
# Barbados             0.021507  0.067382
# Belarus              0.048409  0.511385
# Belgium              0.432342  0.890422
# Belize               0.024873  0.016257
#
# [20 rows x 169 columns]

# %%
# make plot of countries that the a country talks about the most
def covers_most(df, country, log_scale=True):
    df_copy = df.copy()

    df_copy["ISO"] = df_copy.index.map(gdelt_name_to_ISO_dict)
    df_copy = df_copy.reset_index()

    if log_scale:
        df_copy[country] = np.log(df_copy[country])

    fig = px.choropleth(df_copy, locations='ISO', color=country, hover_name='Target country',
                        projection='natural earth', title=f'Countries that {country} covers the most')
    fig.show()

# %%
covers_most(final_df, "United States", log_scale=False)

# %%
# make function to show what countries a country is covered by most
def most_covered_by(df, country, log_scale=True):
    df_copy = df.copy()
    
    # switch colums and rows
    transpose = df_copy.T

    transpose["ISO"] = transpose.index.map(gdelt_name_to_ISO_dict)
    transpose = transpose.reset_index()

    if log_scale:
        transpose[country] = np.log(transpose[country])
    
    fig = px.choropleth(transpose, locations='ISO', color=country,
                        projection='natural earth')
    # set legend title
    fig.update_layout(coloraxis_colorbar=dict(title=f'% of coverage that mentions {country}'))
    # set subtitle
    fig.update_layout(title=f'Percentage of news coverage that explicitly mentions {country}, per country')
 
    fig.show()

# %%
most_covered_by(final_df, "Spain", log_scale=False)

# %% [markdown]
# Finally we make a map of which countries are covered most by other countries

# %%
copied_df = final_df.copy()

# set the entry of afghanistan in the afghanistan column to 0
for country in copied_df.columns:
    copied_df.loc[country, country] = None
copied_df["average"] = copied_df.mean(axis=1)

copied_df["ISO"] = copied_df.index.map(gdelt_name_to_ISO_dict)
cp_reset = copied_df.reset_index()

# %%
fig = px.choropleth(cp_reset, locations='ISO', color="average", 
                    color_continuous_scale='RdBu_r', hover_name='Target country',
                    projection='natural earth', title=f'Countries most covered in global news, as percent of global news coverage')

fig.update_layout(
    template='plotly_dark',
    width=1200,
    height=600,
    coloraxis_colorbar=dict(title=f'%'),
    margin={"r":0,"t":70,"l":0,"b":10},
    title={
    'text': f'<b>Countries most covered in global news, as percent of global news coverage</b>',
    'y':0.93,  # Adjust the vertical position of the title
    'x':0.5,  # Center the title horizontally
    'xanchor': 'center',
    'yanchor': 'top',
    'font': {'size': 18}},  # Adjust font size as needed,
)



fig.write_image("../../figs/global_news_coverage.png", width=1200, height=600)

fig.show()

# %% [markdown]
# Then we make a graph like the one above, but we draw lines from each country to each country, making them thicker as the coverage increases. For that we need the average coordinates of each country:

# %%
country_coordinates = pd.read_csv("https://gist.githubusercontent.com/tadast/8827699/raw/61b2107766d6fd51e2bd02d9f78f6be081340efc/countries_codes_and_coordinates.csv")

country_coordinates.head()

# remove quotes from both sides of all strings in the dataframe
country_coordinates = country_coordinates.map(lambda x: x.replace('"', "").strip())

# %% [markdown]
# We can then make a function to find the coordinates from the alpha_3 ISO code:

# %%
def get_coordinates(alpha_3):
    try:
        return country_coordinates[country_coordinates['Alpha-3 code'] == alpha_3][['Latitude (average)', 'Longitude (average)']].values[0]
    except:
        return [None, None]

# %% [markdown]
# And then we can make a plot:

# %%
def plot_coverage_lines_country(cp_reset, source_country):

    fig = go.Figure()

    # don't display the legend
    fig.update_layout(showlegend=False)

    fig.update_layout(
        template='plotly_dark',
        width=1200,
        height=600,
        coloraxis_colorbar=dict(title=f'%'),
        margin={"r":0,"t":70,"l":0,"b":10},
        title={
        'text': f'<b>News coverage network of {source_country}</b>',
        'y':0.93,  # Adjust the vertical position of the title
        'x':0.5,  # Center the title horizontally
        'xanchor': 'center',
        'yanchor': 'top',
        'font': {'size': 18}},  # Adjust font size as needed,
    )

    lines = []

    source_country_coords = get_coordinates(gdelt_name_to_ISO_dict[source_country])

    for i, target_country in enumerate(cp_reset['Target country']):
        if target_country != source_country:
            intensity = 1.5 * float(cp_reset[cp_reset["Target country"] == target_country][source_country].iloc[0])

            print(f"Processing {i+1}/{len(cp_reset)}", end="\r")
            try:
                target_country_coords = get_coordinates(gdelt_name_to_ISO_dict[target_country])
            except:
                pass

            if target_country_coords[0]:
                try:
                    lines.append(
                        go.Scattergeo(
                            lon = [source_country_coords[1], target_country_coords[1]],
                            lat = [source_country_coords[0], target_country_coords[0]],
                            mode = 'lines',
                            line = dict(width = intensity, color = 'white'),
                            opacity = 0.2,
                        )
                    )
                except:
                    pass
    # Add lines to the figure
    for i, line in enumerate(lines):
        print(f"Adding lines {i+1}/{len(lines)}", end="\r")
        fig.add_trace(line)

    # fig.write_image("../../figs/global_news_lines_USA.png", width=1200, height=600)

    fig.show()

# %%
def plot_coverage_lines_world(cp_reset, color):
    fig = go.Figure()

    if color == "black":
        line_color = "white"
    else:
        line_color = "black"

    if color == "black":
        fig.update_layout(template='plotly_dark')

    fig.update_layout(
        showlegend=False,
        width=1200,
        height=600,
        coloraxis_colorbar=dict(title=f'%'),
        margin={"r":0,"t":70,"l":0,"b":10},
        title={
        'text': f'<b>Global news coverage network</b>',
        'y':0.93,  # Adjust the vertical position of the title
        'x':0.5,  # Center the title horizontally
        'xanchor': 'center',
        'yanchor': 'top',
        'font': {'size': 18}},  # Adjust font size as needed,
    )

    lines = []

    for i, target_country in enumerate(cp_reset['Target country']):
        print(f"Processing {i+1}/{len(cp_reset)}", end="\r")
        try:
            target_country_coords = get_coordinates(gdelt_name_to_ISO_dict[target_country])
        except:
            pass
        if target_country_coords[0]:
            for source_country in cp_reset.columns[1:]:
                if source_country != target_country and source_country != "ISO":
                    try:
                        source_country_coords = get_coordinates(gdelt_name_to_ISO_dict[source_country])
                    except:
                        pass
                    if source_country_coords[0]:
                        #print(target_country, source_country)
                        intensity = float(cp_reset[cp_reset["Target country"] == target_country][source_country].iloc[0])

                        try:
                            if intensity > 10:
                                lines.append(
                                    go.Scattergeo(
                                        lon = [source_country_coords[1], target_country_coords[1]],
                                        lat = [source_country_coords[0], target_country_coords[0]],
                                        mode = 'lines',
                                        line = dict(width = intensity,color = line_color),
                                        opacity = 0.2,
                                    ))
                            elif intensity > 5:
                                lines.append(
                                    go.Scattergeo(
                                        lon = [source_country_coords[1], target_country_coords[1]],
                                        lat = [source_country_coords[0], target_country_coords[0]],
                                        mode = 'lines',
                                        line = dict(width = intensity / 3,color = line_color),
                                        opacity = 0.2,
                                    ))
                            elif intensity > 1:
                                lines.append(
                                    go.Scattergeo(
                                        lon = [source_country_coords[1], target_country_coords[1]],
                                        lat = [source_country_coords[0], target_country_coords[0]],
                                        mode = 'lines',
                                        line = dict(width = 0.1,color = line_color),
                                        opacity = 0.15,
                                    ))
                            elif intensity > 0.5:
                                lines.append(
                                    go.Scattergeo(
                                        lon = [source_country_coords[1], target_country_coords[1]],
                                        lat = [source_country_coords[0], target_country_coords[0]],
                                        mode = 'lines',
                                        line = dict(width = 0.05,color = line_color),
                                        opacity = 0.1,
                                    )
                            )
                        except:
                            pass

    # Add lines to the figure
    for i, line in enumerate(lines):
        print(f"Adding lines {i+1}/{len(lines)}", end="\r")
        fig.add_trace(line)

    # fig.write_image("../../figs/global_news_lines.png", width=1200, height=600)

    fig.show()

# %%
plot_coverage_lines_world(cp_reset, "black")
# Out:
# Adding lines 7635/7635
# <div>                            <div id="6b4c4adb-9033-4af8-9bca-4f80aff834d1" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b4c4adb-9033-4af8-9bca-4f80aff834d1")) {                    Plotly.newPlot(                        "6b4c4adb-9033-4af8-9bca-4f80aff834d1",                        [{"lat":["41","33"],"line":{"color":"white","width":0.05},"lon":["20","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["40","33"],"line":{"color":"white","width":0.1},"lon":["45","65"],"mode":"lines","opacity":0.15,"type":"scattergeo"},{"lat":["-27","33"],"line":{"color":"white","width":0.05},"lon":["133","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["40.5","33"],"line":{"color":"white","width":0.1},"lon":["47.5","65"],"mode":"lines","opacity":0.15,"type":"scattergeo"},{"lat":["26","33"],"line":{"color":"white","width":0.05},"lon":["50.55","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["24","33"],"line":{"color":"white","width":0.1},"lon":["90","65"],"mode":"lines","opacity":0.15,"type":"scattergeo"},{"lat":["53","33"],"line":{"color":"white","width":0.05},"lon":["28","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["50.8333","33"],"line":{"color":"white","width":0.05},"lon":["4","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["44","33"],"line":{"color":"white","width":0.05},"lon":["18","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["4.5","33"],"line":{"color":"white","width":0.05},"lon":["114.6667","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["43","33"],"line":{"color":"white","width":0.05},"lon":["25","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["13","33"],"line":{"color":"white","width":0.1},"lon":["105","65"],"mode":"lines","opacity":0.15,"type":"scattergeo"},{"lat":["60","33"],"line":{"color":"white","width":0.05},"lon":["-95","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["15","33"],"line":{"color":"white","width":0.05},"lon":["19","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["35","33"],"line":{"color":"white","width":0.05},"lon":["105","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["-1","33"],"line":{"color":"white","width":0.05},"lon":["15","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["45.1667","33"],"line":{"color":"white","width":0.05},"lon":["15.5","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["21.5","33"],"line":{"color":"white","width":0.05},"lon":["-80","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["35","33"],"line":{"color":"white","width":0.05},"lon":["33","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["49.75","33"],"line":{"color":"white","width":0.05},"lon":["15.5","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["56","33"],"line":{"color":"white","width":0.05},"lon":["10","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["27","33"],"line":{"color":"white","width":0.05},"lon":["30","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["8","33"],"line":{"color":"white","width":0.1},"lon":["38","65"],"mode":"lines","opacity":0.15,"type":"scattergeo"},{"lat":["64","33"],"line":{"color":"white","width":0.05},"lon":["26","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["46","33"],"line":{"color":"white","width":0.05},"lon":["2","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["42","33"],"line":{"color":"white","width":0.05},"lon":["43.5","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["39","33"],"line":{"color":"white","width":0.05},"lon":["22","65"],"mode":"lines","opacity":0.1,"type":"scattergeo"},{"lat":["13.4667","33"],"line":{"color":"white","width ...

# %%
plot_coverage_lines_country(cp_reset, "India")
# Out:
# Adding lines 232/232
# <div>                            <div id="95515ee0-ec7a-40e7-aac4-eb3743044834" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95515ee0-ec7a-40e7-aac4-eb3743044834")) {                    Plotly.newPlot(                        "95515ee0-ec7a-40e7-aac4-eb3743044834",                        [{"lat":["20","33"],"line":{"color":"white","width":1.812469525267994},"lon":["77","65"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","41"],"line":{"color":"white","width":0.03203447549770291},"lon":["77","20"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","28"],"line":{"color":"white","width":0.06251491194486983},"lon":["77","3"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","-14.3333"],"line":{"color":"white","width":0.003463093415007657},"lon":["77","-170"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","42.5"],"line":{"color":"white","width":0.004544506125574273},"lon":["77","1.6"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","-12.5"],"line":{"color":"white","width":0.03982321975497703},"lon":["77","18.5"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","18.25"],"line":{"color":"white","width":1.0280162136294027},"lon":["77","-63.1667"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","17.05"],"line":{"color":"white","width":0.02108677258805513},"lon":["77","-61.8"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","-34"],"line":{"color":"white","width":0.3568942189892803},"lon":["77","-64"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","40"],"line":{"color":"white","width":0.06289823889739662},"lon":["77","45"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","12.5"],"line":{"color":"white","width":0.0046868108728943345},"lon":["77","-69.9667"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","-27"],"line":{"color":"white","width":2.5930603943338433},"lon":["77","133"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","47.3333"],"line":{"color":"white","width":0.3087986600306279},"lon":["77","13.3333"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","40.5"],"line":{"color":"white","width":0.08138097243491577},"lon":["77","47.5"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","26"],"line":{"color":"white","width":0.22185723583460948},"lon":["77","50.55"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","24"],"line":{"color":"white","width":1.9798456929555897},"lon":["77","90"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","13.1667"],"line":{"color":"white","width":0.03414090735068912},"lon":["77","-59.5333"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","53"],"line":{"color":"white","width":0.19842450229709033},"lon":["77","28"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","50.8333"],"line":{"color":"white","width":0.5082531202143951},"lon":["77","4"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","17.25"],"line":{"color":"white","width":0.011602143950995404},"lon":["77","-88.75"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","9.5"],"line":{"color":"white","width":0.01712457886676876},"lon":["77","2.25"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","32.3333"],"line":{"color":"white","width":0.10786458652373661},"lon":["77","-64.75"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","27.5"],"line":{"color":"white","width":0.3972875191424196},"lon":["77","90.5"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20","-17"],"line":{"color":"white","width":0.056316730474732006},"lon":["77","-65"],"mode":"lines","opacity":0.2,"type":"scattergeo"},{"lat":["20 ...
